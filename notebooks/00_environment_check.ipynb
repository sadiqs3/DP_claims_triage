# %% [markdown]
# # 00 — Environment and Project Setup Check
#
# This notebook validates that the local project environment is ready for the
# Device Protection Claims Triage capstone.
#
# It covers:
#
# - Python and package availability
# - Project-folder structure
# - Runtime data-path availability
# - Import checks for source modules
# - Basic file-read validation
# - Test-discovery readiness
#
# This notebook should remain lightweight and reusable. Its purpose is to confirm
# that the project can be opened and executed reliably before running data,
# triage, or agentic-workflow notebooks.

# %%
import sys
import pandas as pd
import numpy as np

print("Python executable:", sys.executable)
print("Pandas version:", pd.__version__)
print("NumPy version:", np.__version__)
print("Environment check passed")
# Out:
# Python executable: /opt/anaconda3/envs/dpclaims/bin/python
# Pandas version: 3.0.3
# NumPy version: 2.4.6
# Environment check passed
